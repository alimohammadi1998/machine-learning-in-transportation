# %% [markdown]
# ## Libraries

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

import os
import sys
import cv2
import time
import json
import numpy as np
import matplotlib.pyplot as plt

from glob import glob
from PIL import Image

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader

import torchvision
import torchvision.models as models
import torchvision.datasets as datasets
import torchvision.transforms as transforms

from train import train_model
from data_utils import create_validation_data
from vis_utils import imshow

# %% [markdown]
# Helper functions

# %%
def get_model(model_name, num_classes, pretrained=True):
    return models.__dict__[model_name](pretrained)


def read_annotations(path):
    """ Read Bounding Boxes from a json file.
    """
    anno_classes = [f.split('_')[0] for f in os.listdir(path)]
    bb_json = {}
    
    for c in anno_classes:
        j = json.load(open(f'{path}/{c}_labels.json', 'r'))
        for l in j:
            if 'annotations' in l and len(l['annotations']) > 0:
                fname = l['filename'].split('/')[-1]
                bb_json[fname] = sorted(
                    l['annotations'], key=lambda x: x['height'] * x['width'])[-1]
    return bb_json


def bbox_to_r1c1r2c2(bbox):
    """ Convert BB from [h, w, x, y] to [r1, c1, r2, c2] format.
    """
    
    # extract h, w, x, y and convert to list
    bb = []
    bb.append(bbox['height'])
    bb.append(bbox['width'])
    bb.append(max(bbox['x'], 0))
    bb.append(max(bbox['y'], 0))
    
    # convert to float
    bb = [float(x) for x in bb]
    
    # convert to [r1, c1, r2, c2] format
    r1 = bb[3]
    c1 = bb[2]
    r2 = r1 + bb[0]
    c2 = c1 + bb[1]
    
    return [r1, c1, r2, c2]


def plot_bbox(img, bbox, w, h, color='red'):
    """ Plot bounding box on the image tensor. 
    """
    img = img.cpu().numpy().transpose((1, 2, 0))  # (H, W, C)
    
    # denormalize
    mean = np.array([0.485, 0.456, 0.406])
    std  = np.array([0.229, 0.224, 0.225])
    img = std * img + mean
    img = np.clip(img, 0, 1)
    
    # scale
    hs, ws = img.shape[:2]
    h_scale = h / hs
    w_scale = w / ws
    
    bb = np.array(bbox, dtype=np.float32)
    bx, by = bb[1], bb[0]
    bw = bb[3] - bb[1]
    bh = bb[2] - bb[0]
    
    bx *= w * w_scale
    by *= h * h_scale
    bw *= w * w_scale
    bh *= h * h_scale
    
    # scale image
    img = cv2.resize(img, (w, h))
    
    # create BB rectangle
    rect = plt.Rectangle((bx, by), bw, bh, color=color, fill=False, lw=3)
    
    # plot
    plt.figure(figsize=(10, 10))
    plt.axis('off')
    plt.imshow(img)
    plt.gca().add_patch(rect)
    plt.show()

# %% [markdown]
# ### Read annotations (bounding boxes)

# %%
bb_json = read_annotations(anno_dir)

# %%
print(list(bb_json.keys())[:5])
# Out:
# ['img_07917.jpg', 'img_07915.jpg', 'img_07914.jpg', 'img_07912.jpg', 'img_07904.jpg']

# %%
print(bb_json['img_07917.jpg'])
# Out:
# {'class': 'rect', 'height': 151.06975503141317, 'width': 383.68430384213445, 'x': 547.1578480789353, 'y': 193.3597426816281}

# %% [markdown]
# ### Files structure

# %%
print(os.listdir(DATA_DIR))
# Out:
# ['annotations', 'sample', 'test', 'train', 'valid']

# %%
# all images for each fish class is in a separate directory
print(os.listdir(f'{DATA_DIR}/train'))
# Out:
# ['ALB', 'BET', 'DOL', 'LAG', 'NoF', 'OTHER', 'SHARK', 'YFT']

# %% [markdown]
# ### Annotations

# %%
anno_files = os.listdir(anno_dir)
anno_files
# Out:
# ['alb_labels.json',
#  'bet_labels.json',
#  'dol_labels.json',
#  'lag_labels.json',
#  'other_labels.json',
#  'shark_labels.json',
#  'yft_labels.json']

# %%
filename = f'{anno_dir}/{anno_files[0]}'
print(open(filename, 'r').read())
# Out:
# [
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 151.06975503141317,
#                 "width": 383.68430384213445,
#                 "x": 547.1578480789353,
#                 "y": 193.3597426816281
#             }
#         ],
#         "class": "image",
#         "filename": "img_07917.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 65.00000000000023,
#                 "width": 166.00000000000063,
#                 "x": 469.00000000000165,
#                 "y": 448.0000000000016
#             },
#             {
#                 "class": "rect",
#                 "height": 143.0000000000005,
#                 "width": 98.00000000000036,
#                 "x": 92.00000000000033,
#                 "y": 495.00000000000176
#             }
#         ],
#         "class": "image",
#         "filename": "img_07915.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 85.00000000000034,
#                 "width": 251.00000000000085,
#                 "x": 334.0000000000012,
#                 "y": 244.00000000000085
#             }
#         ],
#         "class": "image",
#         "filename": "img_07914.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 231.0000000000008,
#                 "width": 199.00000000000068,
#                 "x": 388.00000000000136,
#                 "y": 126.00000000000045
#             }
#         ],
#         "class": "image",
#         "filename": "img_07912.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 158.0000000000005,
#                 "width": 73.00000000000027,
#                 "x": 116.00000000000041,
#                 "y": 495.00000000000176
#             }
#         ],
#         "class": "image",
#         "filename": "img_07904.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 150.0000000000005,
#                 "width": 90.00000000000034,
#                 "x": 638.0000000000023,
#                 "y": 332.0000000000012
#             }
#         ],
#         "class": "image",
#         "filename": "img_07903.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 113.0000000000004,
#                 "width": 323.0000000000012,
#                 "x": 275.00000000000097,
#                 "y": 62.00000000000023
#             },
#             {
#                 "class": "rect",
#                 "height": 109.0000000000004,
#                 "width": 272.00000000000097,
#                 "x": 495.00000000000176,
#                 "y": 177.00000000000063
#             }
#         ],
#         "class": "image",
#         "filename": "img_07892.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 191.00000000000063,
#                 "width": 85.00000000000034,
#                 "x": 656.0000000000023,
#                 "y": 430.00000000000153
#             },
#             {
#                 "class": "rect",
#                 "height": 93.00000000000034,
#                 "width": 96.00000000000034,
#                 "x": 838.000000000003,
#                 "y": 310.0000000000011
#             }
#         ],
#         "class": "image",
#         "filename": "img_07890.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 160.00000000000057,
#                 "width": 235.0000000000008,
#                 "x": 765.0000000000027,
#                 "y": 12.000000000000057
#             }
#         ],
#         "class": "image",
#         "filename": "img_07885.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 152.00000000000057,
#                 "width": 55.00000000000023,
#                 "x": 569.000000000002,
#                 "y": 370.0000000000013
#             }
#         ],
#         "class": "image",
#         "filename": "img_07883.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 162.00000000000057,
#                 "width": 85.00000000000031,
#                 "x": 104.00000000000037,
#                 "y": 487.0000000000017
#             },
#             {
#                 "class": "rect",
#                 "height": 48.00000000000017,
#                 "width": 97.00000000000034,
#                 "x": 140.0000000000005,
#                 "y": 418.0000000000015
#             },
#             {
#                 "class": "rect",
#                 "height": 49.00000000000017,
#                 "width": 151.00000000000057,
#                 "x": 411.0000000000015,
#                 "y": 394.0000000000014
#             }
#         ],
#         "class": "image",
#         "filename": "img_07879.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 250.0000000000009,
#                 "width": 102.00000000000023,
#                 "x": 1009.0000000000036,
#                 "y": 542.000000000002
#             },
#             {
#                 "class": "rect",
#                 "height": 245.0000000000009,
#                 "width": 156.00000000000057,
#                 "x": 195.00000000000068,
#                 "y": 348.00000000000125
#             }
#         ],
#         "class": "image",
#         "filename": "img_07878.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 156.00000000000057,
#                 "width": 352.00000000000136,
#                 "x": 592.000000000002,
#                 "y": 81.00000000000028
#             }
#         ],
#         "class": "image",
#         "filename": "img_07877.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 187.00000000000063,
#                 "width": 88.00000000000034,
#                 "x": 655.0000000000023,
#                 "y": 432.00000000000153
#             },
#             {
#                 "class": "rect",
#                 "height": 87.00000000000034,
#                 "width": 104.00000000000034,
#                 "x": 837.000000000003,
#                 "y": 309.0000000000011
#             }
#         ],
#         "class": "image",
#         "filename": "img_07876.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 35.00000000000017,
#                 "width": 166.0000000000005,
#                 "x": 423.00000000000153,
#                 "y": 391.00000000000136
#             }
#         ],
#         "class": "image",
#         "filename": "img_07874.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 179.00000000000068,
#                 "width": 210.0000000000008,
#                 "x": 611.0000000000022,
#                 "y": 448.0000000000016
#             }
#         ],
#         "class": "image",
#         "filename": "img_07871.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 107.00000000000034,
#                 "width": 119.00000000000045,
#                 "x": 478.0000000000017,
#                 "y": 284.000000000001
#             }
#         ],
#         "class": "image",
#         "filename": "img_07869.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 199.0000000000007,
#                 "width": 267.00000000000114,
#                 "x": 782.0000000000027,
#                 "y": 180.00000000000065
#             }
#         ],
#         "class": "image",
#         "filename": "img_07868.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 98.00000000000036,
#                 "width": 274.00000000000097,
#                 "x": 395.0000000000014,
#                 "y": 60.00000000000021
#             },
#             {
#                 "class": "rect",
#                 "height": 103.00000000000036,
#                 "width": 338.00000000000114,
#                 "x": 776.0000000000027,
#                 "y": 108.00000000000038
#             },
#             {
#                 "class": "rect",
#                 "height": 114.0000000000004,
#                 "width": 251.00000000000102,
#                 "x": 957.0000000000033,
#                 "y": 221.0000000000008
#             },
#             {
#                 "class": "rect",
#                 "height": 132.00000000000045,
#                 "width": 317.00000000000125,
#                 "x": 746.0000000000027,
#                 "y": 228.00000000000074
#             },
#             {
#                 "class": "rect",
#                 "height": 82.00000000000028,
#                 "width": 307.00000000000114,
#                 "x": 847.000000000003,
#                 "y": 435.00000000000153
#             }
#         ],
#         "class": "image",
#         "filename": "img_07863.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 159.0000000000005,
#                 "width": 108.00000000000045,
#                 "x": 550.0000000000019,
#                 "y": 425.00000000000153
#             }
#         ],
#         "class": "image",
#         "filename": "img_07862.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 112.0000000000004,
#                 "width": 153.0000000000005,
#                 "x": 397.0000000000014,
#                 "y": 401.0000000000014
#             },
#             {
#                 "class": "rect",
#                 "height": 64.00000000000023,
#                 "width": 104.00000000000037,
#                 "x": 142.0000000000005,
#                 "y": 411.0000000000015
#             },
#             {
#                 "class": "rect",
#                 "height": 157.00000000000057,
#                 "width": 75.00000000000028,
#                 "x": 106.00000000000037,
#                 "y": 486.0000000000017
#             }
#         ],
#         "class": "image",
#         "filename": "img_07858.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 52.000000000000185,
#                 "width": 116.00000000000045,
#                 "x": 574.000000000002,
#                 "y": 59.00000000000021
#             }
#         ],
#         "class": "image",
#         "filename": "img_07851.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 186.00000000000068,
#                 "width": 388.00000000000136,
#                 "x": 529.0000000000019,
#                 "y": 144.0000000000005
#             }
#         ],
#         "class": "image",
#         "filename": "img_07850.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 66.00000000000023,
#                 "width": 124.00000000000045,
#                 "x": 257.0000000000009,
#                 "y": 516.0000000000018
#             }
#         ],
#         "class": "image",
#         "filename": "img_07836.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 131.00000000000045,
#                 "width": 323.0000000000011,
#                 "x": 267.00000000000097,
#                 "y": 196.00000000000068
#             }
#         ],
#         "class": "image",
#         "filename": "img_07826.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 65.00000000000026,
#                 "width": 101.00000000000034,
#                 "x": 297.0000000000011,
#                 "y": 175.00000000000063
#             }
#         ],
#         "class": "image",
#         "filename": "img_07822.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 106.00000000000038,
#                 "width": 332.00000000000114,
#                 "x": 287.000000000001,
#                 "y": 77.00000000000027
#             },
#             {
#                 "class": "rect",
#                 "height": 112.0000000000004,
#                 "width": 304.00000000000114,
#                 "x": 186.00000000000065,
#                 "y": 314.00000000000114
#             }
#         ],
#         "class": "image",
#         "filename": "img_07814.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 134.00000000000045,
#                 "width": 138.0000000000005,
#                 "x": 439.00000000000153,
#                 "y": 384.00000000000136
#             }
#         ],
#         "class": "image",
#         "filename": "img_07811.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 181.00000000000065,
#                 "width": 374.00000000000136,
#                 "x": 636.0000000000023,
#                 "y": 182.00000000000065
#             }
#         ],
#         "class": "image",
#         "filename": "img_07810.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 102.0000000000004,
#                 "width": 111.0000000000004,
#                 "x": 407.0000000000014,
#                 "y": 360.00000000000125
#             }
#         ],
#         "class": "image",
#         "filename": "img_07807.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 157.00000000000063,
#                 "width": 156.00000000000057,
#                 "x": 611.0000000000022,
#                 "y": 467.00000000000165
#             }
#         ],
#         "class": "image",
#         "filename": "img_07802.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 166.00000000000057,
#                 "width": 411.0000000000015,
#                 "x": 579.000000000002,
#                 "y": 313.00000000000114
#             },
#             {
#                 "class": "rect",
#                 "height": 101.00000000000036,
#                 "width": 327.00000000000114,
#                 "x": 247.00000000000088,
#                 "y": 99.00000000000036
#             }
#         ],
#         "class": "image",
#         "filename": "img_07801.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 50.00000000000023,
#                 "width": 170.00000000000063,
#                 "x": 459.00000000000165,
#                 "y": 480.0000000000017
#             }
#         ],
#         "class": "image",
#         "filename": "img_07797.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 129.00000000000045,
#                 "width": 261.0000000000009,
#                 "x": 886.0000000000032,
#                 "y": 204.00000000000074
#             }
#         ],
#         "class": "image",
#         "filename": "img_07794.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 129.00000000000045,
#                 "width": 196.00000000000068,
#                 "x": 298.0000000000011,
#                 "y": 258.0000000000009
#             }
#         ],
#         "class": "image",
#         "filename": "img_07789.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 120.00000000000044,
#                 "width": 191.00000000000068,
#                 "x": 750.0000000000026,
#                 "y": 29.0000000000001
#             }
#         ],
#         "class": "image",
#         "filename": "img_07785.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 71.00000000000023,
#                 "width": 202.00000000000074,
#                 "x": 164.00000000000057,
#                 "y": 379.00000000000136
#             }
#         ],
#         "class": "image",
#         "filename": "img_07773.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 85.00000000000028,
#                 "width": 91.00000000000034,
#                 "x": 771.0000000000027,
#                 "y": 284.000000000001
#             },
#             {
#                 "class": "rect",
#                 "height": 55.0000000000002,
#                 "width": 94.00000000000034,
#                 "x": 589.000000000002,
#                 "y": 49.00000000000017
#             }
#         ],
#         "class": "image",
#         "filename": "img_07772.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 72.00000000000028,
#                 "width": 179.00000000000057,
#                 "x": 379.00000000000136,
#                 "y": 401.0000000000014
#             }
#         ],
#         "class": "image",
#         "filename": "img_07771.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 179.00000000000065,
#                 "width": 83.00000000000034,
#                 "x": 585.000000000002,
#                 "y": 248.00000000000088
#             }
#         ],
#         "class": "image",
#         "filename": "img_07768.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 170.0000000000006,
#                 "width": 143.0000000000005,
#                 "x": 88.00000000000031,
#                 "y": 104.00000000000037
#             },
#             {
#                 "class": "rect",
#                 "height": 98.00000000000036,
#                 "width": 378.00000000000136,
#                 "x": 505.0000000000018,
#                 "y": 107.00000000000038
#             }
#         ],
#         "class": "image",
#         "filename": "img_07767.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 72.00000000000026,
#                 "width": 194.00000000000068,
#                 "x": 144.0000000000005,
#                 "y": 114.0000000000004
#             },
#             {
#                 "class": "rect",
#                 "height": 86.0000000000003,
#                 "width": 376.00000000000125,
#                 "x": 564.000000000002,
#                 "y": 107.00000000000038
#             }
#         ],
#         "class": "image",
#         "filename": "img_07766.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 127.00000000000045,
#                 "width": 121.00000000000045,
#                 "x": 636.0000000000023,
#                 "y": 353.00000000000125
#             }
#         ],
#         "class": "image",
#         "filename": "img_07763.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 124.00000000000045,
#                 "width": 110.00000000000045,
#                 "x": 486.0000000000017,
#                 "y": 305.0000000000011
#             }
#         ],
#         "class": "image",
#         "filename": "img_07755.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 89.00000000000031,
#                 "width": 372.00000000000136,
#                 "x": 559.0000000000019,
#                 "y": 102.00000000000037
#             },
#             {
#                 "class": "rect",
#                 "height": 67.00000000000024,
#                 "width": 196.00000000000068,
#                 "x": 145.0000000000005,
#                 "y": 115.00000000000041
#             }
#         ],
#         "class": "image",
#         "filename": "img_07749.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 132.00000000000045,
#                 "width": 36.000000000000114,
#                 "x": 584.000000000002,
#                 "y": 383.00000000000136
#             }
#         ],
#         "class": "image",
#         "filename": "img_07745.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 101.05823052798263,
#                 "width": 112.00620550184749,
#                 "x": 636.6668523262908,
#                 "y": 354.5459587690059
#             }
#         ],
#         "class": "image",
#         "filename": "img_07741.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 117.90126894931308,
#                 "width": 107.79544589651482,
#                 "x": 807.6236923027949,
#                 "y": 277.06798203088584
#             },
#             {
#                 "class": "rect",
#                 "height": 145.69228234450838,
#                 "width": 113.69050934398047,
#                 "x": 565.0839390356365,
#                 "y": 427.81317590179333
#             },
#             {
#                 "class": "rect",
#                 "height": 107.79544589651482,
#                 "width": 115.37481318611356,
#                 "x": 644.2462196158896,
#                 "y": 320.859881926345
#             }
#         ],
#         "class": "image",
#         "filename": "img_07740.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 196.22139760849961,
#                 "width": 84.21519210665224,
#                 "x": 654.3520426686878,
#                 "y": 427.81317590179333
#             },
#             {
#                 "class": "rect",
#                 "height": 101.05823052798263,
#                 "width": 105.26899013331524,
#                 "x": 832.8882499347906,
#                 "y": 304.01684350501455
#             }
#         ],
#         "class": "image",
#         "filename": "img_07739.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 232.43393021436003,
#                 "width": 160.85101692370574,
#                 "x": 305.7011473471476,
#                 "y": 352.0195030058063
#             }
#         ],
#         "class": "image",
#         "filename": "img_07735.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 144.8501304234418,
#                 "width": 150.74519387090749,
#                 "x": 221.48595524049534,
#                 "y": 63.16139407998918
#             }
#         ],
#         "class": "image",
#         "filename": "img_07732.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 90.95240747518437,
#                 "width": 202.95861297703186,
#                 "x": 198.74785337169925,
#                 "y": 379.81051640100156
#             }
#         ],
#         "class": "image",
#         "filename": "img_07730.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 116.2169651071801,
#                 "width": 88.42595171198491,
#                 "x": 725.0928040382756,
#                 "y": 340.22937611087497
#             }
#         ],
#         "class": "image",
#         "filename": "img_07727.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 127.16494008104485,
#                 "width": 361.283174137538,
#                 "x": 665.3000176425526,
#                 "y": 378.968364479935
#             },
#             {
#                 "class": "rect",
#                 "height": 97.68962284371659,
#                 "width": 275.38367818875275,
#                 "x": 246.75051287249102,
#                 "y": 108.63759781758137
#             }
#         ],
#         "class": "image",
#         "filename": "img_07726.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 124.63848431784527,
#                 "width": 297.2796281364823,
#                 "x": 613.0865985364283,
#                 "y": 197.06354952956622
#             },
#             {
#                 "class": "rect",
#                 "height": 108.63759781758138,
#                 "width": 401.70646634873106,
#                 "x": 618.9816619838939,
#                 "y": 74.95152097492048
#             },
#             {
#                 "class": "rect",
#                 "height": 88.42595171198484,
#                 "width": 303.174691583948,
#                 "x": 285.48950124155107,
#                 "y": 58.108482553590036
#             },
#             {
#                 "class": "rect",
#                 "height": 75.79367289598699,
#                 "width": 90.11025555411788,
#                 "x": 23.580253789862624,
#                 "y": 229.06532253009405
#             }
#         ],
#         "class": "image",
#         "filename": "img_07720.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 28.633165316261795,
#                 "width": 176.0097515029031,
#                 "x": 765.5160962494688,
#                 "y": 369.70469334820325
#             }
#         ],
#         "class": "image",
#         "filename": "img_07710.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 70.74076136958786,
#                 "width": 284.6473493204845,
#                 "x": 369.70469334820325,
#                 "y": 264.435703214888
#             }
#         ],
#         "class": "image",
#         "filename": "img_07709.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 103.58468629118227,
#                 "width": 52.213419106124434,
#                 "x": 877.5223017513161,
#                 "y": 298.9639319786154
#             },
#             {
#                 "class": "rect",
#                 "height": 90.11025555411788,
#                 "width": 69.05645752745488,
#                 "x": 806.7815403817283,
#                 "y": 298.1217800575489
#             }
#         ],
#         "class": "image",
#         "filename": "img_07705.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 42.10759605332612,
#                 "width": 62.319242158922634,
#                 "x": 923.8406574099749,
#                 "y": 193.69494184530012
#             }
#         ],
#         "class": "image",
#         "filename": "img_07704.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 101.05823052798269,
#                 "width": 65.68784984318881,
#                 "x": 821.0981230398592,
#                 "y": 322.54418576847803
#             }
#         ],
#         "class": "image",
#         "filename": "img_07701.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 69.05645752745477,
#                 "width": 128.00709200211134,
#                 "x": 353.7038068479394,
#                 "y": 426.97102398072684
#             }
#         ],
#         "class": "image",
#         "filename": "img_07698.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 250.11912055675714,
#                 "width": 177.69405534503625,
#                 "x": 474.97368348151855,
#                 "y": 152.42949771304052
#             }
#         ],
#         "class": "image",
#         "filename": "img_07694.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 166.7460803711714,
#                 "width": 304.01684350501466,
#                 "x": 821.0981230398592,
#                 "y": 330.96570497914325
#             },
#             {
#                 "class": "rect",
#                 "height": 118.74342087037964,
#                 "width": 353.7038068479394,
#                 "x": 665.3000176425526,
#                 "y": 96.00531900158354
#             },
#             {
#                 "class": "rect",
#                 "height": 103.58468629118224,
#                 "width": 353.70380684793935,
#                 "x": 382.3369721642011,
#                 "y": 61.47709023785612
#             },
#             {
#                 "class": "rect",
#                 "height": 213.90658795089666,
#                 "width": 291.38456468901677,
#                 "x": 344.4401357162076,
#                 "y": 131.37569968637746
#             }
#         ],
#         "class": "image",
#         "filename": "img_07686.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 166.74608037117142,
#                 "width": 145.69228234450838,
#                 "x": 221.48595524049534,
#                 "y": 52.21341910612438
#             }
#         ],
#         "class": "image",
#         "filename": "img_07684.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 83.37304018558575,
#                 "width": 35.37038068479387,
#                 "x": 864.0478710142519,
#                 "y": 296.4374762154158
#             }
#         ],
#         "class": "image",
#         "filename": "img_07681.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 179.37835918716928,
#                 "width": 100.21607860691608,
#                 "x": 532.2400141140421,
#                 "y": 481.71089885005074
#             },
#             {
#                 "class": "rect",
#                 "height": 67.37215368532179,
#                 "width": 54.7398748693239,
#                 "x": 773.937615460134,
#                 "y": 311.5962107946132
#             }
#         ],
#         "class": "image",
#         "filename": "img_07672.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 133.06000352851055,
#                 "width": 380.65266832206805,
#                 "x": 541.5036852457738,
#                 "y": 148.2187381077079
#             }
#         ],
#         "class": "image",
#         "filename": "img_07671.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 122.95418047571223,
#                 "width": 126.3227881599783,
#                 "x": 460.6571008233877,
#                 "y": 322.54418576847803
#             }
#         ],
#         "class": "image",
#         "filename": "img_07670.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 177.6940553450362,
#                 "width": 100.2160786069162,
#                 "x": 527.1871025876429,
#                 "y": 539.8193814036408
#             }
#         ],
#         "class": "image",
#         "filename": "img_07669.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 160.85101692370574,
#                 "width": 146.53443426557487,
#                 "x": 221.48595524049534,
#                 "y": 54.739874869323955
#             }
#         ],
#         "class": "image",
#         "filename": "img_07668.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 45.476203737592186,
#                 "width": 142.32367466024232,
#                 "x": 778.1483750654666,
#                 "y": 289.7002608468837
#             }
#         ],
#         "class": "image",
#         "filename": "img_07664.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 199.59000529276574,
#                 "width": 142.3236746602422,
#                 "x": 672.8793849321513,
#                 "y": 455.6041892969885
#             }
#         ],
#         "class": "image",
#         "filename": "img_07662.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 196.22139760849967,
#                 "width": 130.5335477653109,
#                 "x": 703.1968540905461,
#                 "y": 488.44811421858293
#             },
#             {
#                 "class": "rect",
#                 "height": 189.48418223996748,
#                 "width": 119.58557279144611,
#                 "x": 585.295585141233,
#                 "y": 532.2400141140421
#             },
#             {
#                 "class": "rect",
#                 "height": 144.85013042344184,
#                 "width": 141.48152273917572,
#                 "x": 616.4552062206943,
#                 "y": 342.75583187407454
#             }
#         ],
#         "class": "image",
#         "filename": "img_07657.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 194.53709376636658,
#                 "width": 69.89860944852134,
#                 "x": 117.05911702824659,
#                 "y": 477.5001392447181
#             },
#             {
#                 "class": "rect",
#                 "height": 95.16316708051704,
#                 "width": 108.63759781758142,
#                 "x": 420.2338086121946,
#                 "y": 433.708239349259
#             }
#         ],
#         "class": "image",
#         "filename": "img_07652.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 321.7020338474115,
#                 "width": 100.21607860691608,
#                 "x": 949.9473669630371,
#                 "y": 186.11557455570141
#             },
#             {
#                 "class": "rect",
#                 "height": 188.642030318901,
#                 "width": 375.59975679566895,
#                 "x": 311.5962107946132,
#                 "y": 188.642030318901
#             }
#         ],
#         "class": "image",
#         "filename": "img_07651.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 146.53443426557487,
#                 "width": 316.6491223210124,
#                 "x": 392.4427952169994,
#                 "y": 213.90658795089666
#             }
#         ],
#         "class": "image",
#         "filename": "img_07647.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 163.37747268690532,
#                 "width": 215.59089179302975,
#                 "x": 662.773561879353,
#                 "y": 321.7020338474115
#             }
#         ],
#         "class": "image",
#         "filename": "img_07645.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 63.16139407998918,
#                 "width": 175.16759958183664,
#                 "x": 174.3254476607701,
#                 "y": 349.49304724260674
#             }
#         ],
#         "class": "image",
#         "filename": "img_07640.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 181.0626630293023,
#                 "width": 291.38456468901666,
#                 "x": 360.44102221647154,
#                 "y": 152.42949771304052
#             }
#         ],
#         "class": "image",
#         "filename": "img_07639.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 117.05911702824659,
#                 "width": 102.74253437011572,
#                 "x": 387.38988369060024,
#                 "y": 136.42861121277662
#             }
#         ],
#         "class": "image",
#         "filename": "img_07638.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 179.37835918716917,
#                 "width": 208.01152450343102,
#                 "x": 612.2444466153617,
#                 "y": 444.6562143231238
#             }
#         ],
#         "class": "image",
#         "filename": "img_07636.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 142.32367466024232,
#                 "width": 84.21519210665213,
#                 "x": 617.2973581417608,
#                 "y": 351.17735108473977
#             }
#         ],
#         "class": "image",
#         "filename": "img_07619.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 112.00620550184745,
#                 "width": 322.54418576847803,
#                 "x": 272.0150705044867,
#                 "y": 62.31924215892265
#             },
#             {
#                 "class": "rect",
#                 "height": 152.42949771304052,
#                 "width": 266.1200070570211,
#                 "x": 949.1052150419706,
#                 "y": 207.16937258236447
#             }
#         ],
#         "class": "image",
#         "filename": "img_07617.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 111.16405358078097,
#                 "width": 367.1782375850038,
#                 "x": 656.8784984318874,
#                 "y": 203.80076489809838
#             }
#         ],
#         "class": "image",
#         "filename": "img_07614.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 148.21873810770794,
#                 "width": 58.95063447465657,
#                 "x": 309.06975503141365,
#                 "y": 116.21696510718007
#             },
#             {
#                 "class": "rect",
#                 "height": 48.002659500791765,
#                 "width": 167.5882322922379,
#                 "x": 189.4841822399675,
#                 "y": 456.44634121805507
#             }
#         ],
#         "class": "image",
#         "filename": "img_07608.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 121.26987663357914,
#                 "width": 58.95063447465657,
#                 "x": 840.4676172243892,
#                 "y": 485.92165845538335
#             },
#             {
#                 "class": "rect",
#                 "height": 58.10848255359002,
#                 "width": 118.74342087037962,
#                 "x": 719.19774059081,
#                 "y": 278.7522858730189
#             }
#         ],
#         "class": "image",
#         "filename": "img_07604.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 114.53266126504701,
#                 "width": 137.27076313384305,
#                 "x": 638.3511561684239,
#                 "y": 370.5468452692698
#             }
#         ],
#         "class": "image",
#         "filename": "img_07603.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 109.47974973864791,
#                 "width": 155.79810539730659,
#                 "x": 759.6210328020031,
#                 "y": 343.5979837951411
#             }
#         ],
#         "class": "image",
#         "filename": "img_07587.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 128.0070920021114,
#                 "width": 362.1253260586045,
#                 "x": 540.6615333247073,
#                 "y": 153.27164963410706
#             }
#         ],
#         "class": "image",
#         "filename": "img_07576.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 89.26810363305134,
#                 "width": 302.33253966288146,
#                 "x": 411.81228940152937,
#                 "y": 281.27874163621846
#             }
#         ],
#         "class": "image",
#         "filename": "img_07567.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 81.68873634345266,
#                 "width": 149.06089002877445,
#                 "x": 165.06177652903835,
#                 "y": 368.0203895060702
#             }
#         ],
#         "class": "image",
#         "filename": "img_07566.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 182.7469668714353,
#                 "width": 319.1755780842119,
#                 "x": 645.0883715369561,
#                 "y": 336.8607684266089
#             }
#         ],
#         "class": "image",
#         "filename": "img_07560.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 132.21785160744395,
#                 "width": 118.74342087037965,
#                 "x": 223.1702590826284,
#                 "y": 381.4948202431346
#             }
#         ],
#         "class": "image",
#         "filename": "img_07559.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 158.32456116050616,
#                 "width": 386.5477317695337,
#                 "x": 554.1359640617717,
#                 "y": 192.8527899242336
#             }
#         ],
#         "class": "image",
#         "filename": "img_07558.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 47.16050757972522,
#                 "width": 128.00709200211134,
#                 "x": 568.4525467199026,
#                 "y": 325.0706415316776
#             }
#         ],
#         "class": "image",
#         "filename": "img_07554.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 176.8519034239697,
#                 "width": 426.12887205966024,
#                 "x": 629.0874850366921,
#                 "y": 574.3476101673682
#             }
#         ],
#         "class": "image",
#         "filename": "img_07549.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 139.79721889704268,
#                 "width": 120.4277247125126,
#                 "x": 610.5601427732287,
#                 "y": 353.70380684793935
#             }
#         ],
#         "class": "image",
#         "filename": "img_07542.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 122.95418047571225,
#                 "width": 325.0706415316776,
#                 "x": 266.96215897808753,
#                 "y": 53.897722948257424
#             }
#         ],
#         "class": "image",
#         "filename": "img_07540.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 124.63848431784533,
#                 "width": 230.74962637222706,
#                 "x": 458.1306450601881,
#                 "y": 65.68784984318873
#             }
#         ],
#         "class": "image",
#         "filename": "img_07537.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 146.53443426557487,
#                 "width": 362.1253260586046,
#                 "x": 389.0741875327333,
#                 "y": 215.5908917930297
#             }
#         ],
#         "class": "image",
#         "filename": "img_07527.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 79.16228058025308,
#                 "width": 51.371267185057945,
#                 "x": 804.2550846185287,
#                 "y": 303.174691583948
#             }
#         ],
#         "class": "image",
#         "filename": "img_07522.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 139.79721889704268,
#                 "width": 387.3898836906003,
#                 "x": 597.9278639572308,
#                 "y": 337.70292034767544
#             },
#             {
#                 "class": "rect",
#                 "height": 100.21607860691616,
#                 "width": 305.70114734714764,
#                 "x": 256.8563359252893,
#                 "y": 105.26899013331528
#             }
#         ],
#         "class": "image",
#         "filename": "img_07520.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 91.79455939625092,
#                 "width": 354.54595876900584,
#                 "x": 317.4912742420789,
#                 "y": 194.53709376636664
#             },
#             {
#                 "class": "rect",
#                 "height": 112.00620550184746,
#                 "width": 274.5415262676863,
#                 "x": 394.9692509801989,
#                 "y": 76.63582481705353
#             },
#             {
#                 "class": "rect",
#                 "height": 298.1217800575489,
#                 "width": 281.27874163621834,
#                 "x": 677.9322964585505,
#                 "y": 151.58734579197397
#             }
#         ],
#         "class": "image",
#         "filename": "img_07511.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 100.21607860691614,
#                 "width": 65.6878498431887,
#                 "x": 842.9940729875888,
#                 "y": 304.85899542608104
#             }
#         ],
#         "class": "image",
#         "filename": "img_07492.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 356.23026261113887,
#                 "width": 225.69671484582796,
#                 "x": 919.6298978046423,
#                 "y": 250.11912055675714
#             }
#         ],
#         "class": "image",
#         "filename": "img_07491.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 144.85013042344184,
#                 "width": 192.01063800316706,
#                 "x": 306.5432992682141,
#                 "y": 242.5397532671584
#             }
#         ],
#         "class": "image",
#         "filename": "img_07489.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 112.00620550184746,
#                 "width": 322.5441857684781,
#                 "x": 271.17291858342014,
#                 "y": 59.792786395723084
#             },
#             {
#                 "class": "rect",
#                 "height": 180.22051110823574,
#                 "width": 235.80253789862627,
#                 "x": 964.263949621168,
#                 "y": 196.2213976084997
#             }
#         ],
#         "class": "image",
#         "filename": "img_07488.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 174.32544766077012,
#                 "width": 423.60241629646066,
#                 "x": 544.0301410089734,
#                 "y": 242.5397532671584
#             },
#             {
#                 "class": "rect",
#                 "height": 87.5837997909183,
#                 "width": 104.42683821224887,
#                 "x": 1168.9068664403328,
#                 "y": 562.5574832724369
#             }
#         ],
#         "class": "image",
#         "filename": "img_07486.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 57.266330632523534,
#                 "width": 166.74608037117133,
#                 "x": 367.1782375850037,
#                 "y": 454.76203737592203
#             }
#         ],
#         "class": "image",
#         "filename": "img_07479.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 118.74342087037962,
#                 "width": 320.0177300052784,
#                 "x": 270.33076666235365,
#                 "y": 59.792786395723084
#             },
#             {
#                 "class": "rect",
#                 "height": 196.2213976084997,
#                 "width": 227.38101868796105,
#                 "x": 955.8424304105027,
#                 "y": 203.80076489809838
#             }
#         ],
#         "class": "image",
#         "filename": "img_07477.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 236.64468981969276,
#                 "width": 344.4401357162076,
#                 "x": 610.5601427732287,
# ...
#             }
#         ],
#         "class": "image",
#         "filename": "img_00201.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 163.5600000000025,
#                 "width": 163.56000000000256,
#                 "x": 644.3700000000098,
#                 "y": 338.40000000000515
#             }
#         ],
#         "class": "image",
#         "filename": "img_00197.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 78.96000000000123,
#                 "width": 163.56000000000247,
#                 "x": 188.94000000000287,
#                 "y": 334.1700000000051
#             }
#         ],
#         "class": "image",
#         "filename": "img_00193.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 227.0100000000034,
#                 "width": 70.50000000000108,
#                 "x": 109.98000000000167,
#                 "y": 438.5100000000067
#             },
#             {
#                 "class": "rect",
#                 "height": 112.80000000000172,
#                 "width": 94.47000000000139,
#                 "x": 513.2400000000079,
#                 "y": 389.16000000000594
#             }
#         ],
#         "class": "image",
#         "filename": "img_00191.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 66.270000000001,
#                 "width": 88.8300000000014,
#                 "x": 927.7800000000141,
#                 "y": 201.63000000000306
#             }
#         ],
#         "class": "image",
#         "filename": "img_00188.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 101.52000000000152,
#                 "width": 191.7600000000029,
#                 "x": 208.6800000000032,
#                 "y": 384.93000000000586
#             }
#         ],
#         "class": "image",
#         "filename": "img_00187.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 155.10000000000235,
#                 "width": 270.72000000000423,
#                 "x": 903.8100000000137,
#                 "y": 197.400000000003
#             }
#         ],
#         "class": "image",
#         "filename": "img_00186.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 100.11000000000149,
#                 "width": 80.37000000000126,
#                 "x": 819.2100000000124,
#                 "y": 322.89000000000493
#             }
#         ],
#         "class": "image",
#         "filename": "img_00177.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 59.22000000000088,
#                 "width": 162.15000000000248,
#                 "x": 421.5900000000064,
#                 "y": 382.1100000000058
#             }
#         ],
#         "class": "image",
#         "filename": "img_00163.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 128.31000000000193,
#                 "width": 289.05000000000445,
#                 "x": 365.19000000000557,
#                 "y": 231.24000000000353
#             }
#         ],
#         "class": "image",
#         "filename": "img_00156.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 86.0100000000013,
#                 "width": 150.87000000000228,
#                 "x": 303.15000000000464,
#                 "y": 401.8500000000061
#             }
#         ],
#         "class": "image",
#         "filename": "img_00154.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 314.43000000000484,
#                 "width": 696.5400000000107,
#                 "x": 111.39000000000169,
#                 "y": 575.2800000000087
#             }
#         ],
#         "class": "image",
#         "filename": "img_00136.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 93.06000000000142,
#                 "width": 163.56000000000256,
#                 "x": 349.6800000000053,
#                 "y": 338.40000000000515
#             }
#         ],
#         "class": "image",
#         "filename": "img_00134.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 164.9700000000025,
#                 "width": 243.9300000000037,
#                 "x": 752.9400000000114,
#                 "y": 9.870000000000147
#             }
#         ],
#         "class": "image",
#         "filename": "img_00130.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 152.28000000000236,
#                 "width": 98.70000000000147,
#                 "x": 455.43000000000694,
#                 "y": 373.65000000000566
#             }
#         ],
#         "class": "image",
#         "filename": "img_00121.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 143.82000000000215,
#                 "width": 64.86000000000104,
#                 "x": 448.3800000000068,
#                 "y": 119.85000000000184
#             }
#         ],
#         "class": "image",
#         "filename": "img_00110.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 204.45000000000312,
#                 "width": 78.9600000000012,
#                 "x": 114.21000000000174,
#                 "y": 475.17000000000724
#             },
#             {
#                 "class": "rect",
#                 "height": 153.69000000000233,
#                 "width": 83.19000000000119,
#                 "x": 459.660000000007,
#                 "y": 379.29000000000576
#             },
#             {
#                 "class": "rect",
#                 "height": 101.52000000000157,
#                 "width": 64.86000000000098,
#                 "x": 360.9600000000055,
#                 "y": 616.1700000000094
#             }
#         ],
#         "class": "image",
#         "filename": "img_00097.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 195.99000000000302,
#                 "width": 313.02000000000476,
#                 "x": 816.3900000000124,
#                 "y": 338.40000000000515
#             },
#             {
#                 "class": "rect",
#                 "height": 136.77000000000209,
#                 "width": 327.1200000000049,
#                 "x": 675.3900000000103,
#                 "y": 86.0100000000013
#             },
#             {
#                 "class": "rect",
#                 "height": 135.36000000000206,
#                 "width": 359.5500000000055,
#                 "x": 384.93000000000586,
#                 "y": 70.50000000000108
#             },
#             {
#                 "class": "rect",
#                 "height": 170.6100000000026,
#                 "width": 332.76000000000505,
#                 "x": 332.76000000000505,
#                 "y": 187.53000000000284
#             }
#         ],
#         "class": "image",
#         "filename": "img_00090.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 153.69000000000233,
#                 "width": 389.160000000006,
#                 "x": 545.6700000000083,
#                 "y": 139.59000000000214
#             }
#         ],
#         "class": "image",
#         "filename": "img_00085.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 88.83000000000135,
#                 "width": 200.22000000000304,
#                 "x": 410.31000000000626,
#                 "y": 136.77000000000209
#             }
#         ],
#         "class": "image",
#         "filename": "img_00074.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 156.51000000000232,
#                 "width": 77.55000000000115,
#                 "x": 461.07000000000704,
#                 "y": 503.3700000000077
#             }
#         ],
#         "class": "image",
#         "filename": "img_00057.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 100.11000000000155,
#                 "width": 191.7600000000029,
#                 "x": 186.12000000000285,
#                 "y": 379.29000000000576
#             }
#         ],
#         "class": "image",
#         "filename": "img_00055.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 97.2900000000015,
#                 "width": 97.29000000000144,
#                 "x": 744.4800000000114,
#                 "y": 428.6400000000065
#             }
#         ],
#         "class": "image",
#         "filename": "img_00045.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 138.18000000000205,
#                 "width": 62.04000000000087,
#                 "x": 549.9000000000084,
#                 "y": 383.52000000000584
#             }
#         ],
#         "class": "image",
#         "filename": "img_00043.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 186.12000000000282,
#                 "width": 310.2000000000048,
#                 "x": 774.0900000000117,
#                 "y": 191.76000000000292
#             },
#             {
#                 "class": "rect",
#                 "height": 94.47000000000145,
#                 "width": 331.350000000005,
#                 "x": 547.0800000000083,
#                 "y": 90.24000000000137
#             },
#             {
#                 "class": "rect",
#                 "height": 124.08000000000189,
#                 "width": 262.26000000000397,
#                 "x": 166.38000000000255,
#                 "y": 218.55000000000334
#             }
#         ],
#         "class": "image",
#         "filename": "img_00041.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 115.62000000000177,
#                 "width": 249.57000000000386,
#                 "x": 401.8500000000061,
#                 "y": 121.26000000000184
#             }
#         ],
#         "class": "image",
#         "filename": "img_00039.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 160.74000000000245,
#                 "width": 80.37000000000114,
#                 "x": 744.4800000000114,
#                 "y": 252.39000000000385
#             }
#         ],
#         "class": "image",
#         "filename": "img_00038.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 167.79000000000252,
#                 "width": 108.57000000000164,
#                 "x": 276.3600000000042,
#                 "y": 282.0000000000043
#             }
#         ],
#         "class": "image",
#         "filename": "img_00037.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 64.86000000000104,
#                 "width": 111.39000000000169,
#                 "x": 517.4700000000079,
#                 "y": 514.6500000000078
#             }
#         ],
#         "class": "image",
#         "filename": "img_00032.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 164.97000000000247,
#                 "width": 119.85000000000184,
#                 "x": 587.9700000000089,
#                 "y": 356.7300000000054
#             },
#             {
#                 "class": "rect",
#                 "height": 143.8200000000022,
#                 "width": 93.06000000000142,
#                 "x": 681.0300000000103,
#                 "y": 352.50000000000534
#             }
#         ],
#         "class": "image",
#         "filename": "img_00029.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 193.17000000000303,
#                 "width": 138.1800000000021,
#                 "x": 572.4600000000087,
#                 "y": 527.340000000008
#             },
#             {
#                 "class": "rect",
#                 "height": 195.99000000000302,
#                 "width": 133.9500000000021,
#                 "x": 692.3100000000105,
#                 "y": 494.9100000000075
#             },
#             {
#                 "class": "rect",
#                 "height": 97.29000000000144,
#                 "width": 133.9500000000021,
#                 "x": 614.7600000000093,
#                 "y": 391.980000000006
#             },
#             {
#                 "class": "rect",
#                 "height": 93.06000000000142,
#                 "width": 90.24000000000137,
#                 "x": 638.7300000000097,
#                 "y": 341.2200000000052
#             },
#             {
#                 "class": "rect",
#                 "height": 153.69000000000227,
#                 "width": 80.37000000000114,
#                 "x": 720.510000000011,
#                 "y": 370.83000000000567
#             }
#         ],
#         "class": "image",
#         "filename": "img_00020.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 76.14000000000118,
#                 "width": 149.46000000000228,
#                 "x": 143.82000000000218,
#                 "y": 401.8500000000061
#             }
#         ],
#         "class": "image",
#         "filename": "img_00019.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 76.14000000000118,
#                 "width": 198.81000000000304,
#                 "x": 255.21000000000387,
#                 "y": 338.40000000000515
#             }
#         ],
#         "class": "image",
#         "filename": "img_00015.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 195.99000000000296,
#                 "width": 148.05000000000223,
#                 "x": 480.81000000000734,
#                 "y": 509.0100000000077
#             }
#         ],
#         "class": "image",
#         "filename": "img_00012.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 211.50000000000324,
#                 "width": 80.37000000000126,
#                 "x": 665.5200000000101,
#                 "y": 413.1300000000063
#             },
#             {
#                 "class": "rect",
#                 "height": 107.16000000000162,
#                 "width": 109.98000000000161,
#                 "x": 826.2600000000126,
#                 "y": 301.7400000000046
#             }
#         ],
#         "class": "image",
#         "filename": "img_00010.jpg"
#     },
#     {
#         "annotations": [
#             {
#                 "class": "rect",
#                 "height": 258.03000000000395,
#                 "width": 377.88000000000574,
#                 "x": 266.49000000000404,
#                 "y": 135.36000000000206
#             },
#             {
#                 "class": "rect",
#                 "height": 100.11000000000152,
#                 "width": 360.96000000000555,
#                 "x": 375.0600000000057,
#                 "y": 56.40000000000086
#             },
#             {
#                 "class": "rect",
#                 "height": 105.75000000000162,
#                 "width": 335.58000000000516,
#                 "x": 690.9000000000106,
#                 "y": 88.83000000000135
#             },
#             {
#                 "class": "rect",
#                 "height": 170.61000000000257,
#                 "width": 332.7600000000051,
#                 "x": 805.1100000000123,
#                 "y": 324.30000000000496
#             }
#         ],
#         "class": "image",
#         "filename": "img_00003.jpg"
#     }
# ]

# %% [markdown]
# ### Create validation data

# %%
if not os.path.exists(valid_dir):
    create_validation_data(train_dir, valid_dir, split=0.2, ext='jpg')

# %% [markdown]
# ### Training and Validation dataset

# %%
# training data
train_data = datasets.ImageFolder(train_dir)
train_ds = FishDataset(train_data, bb_json, sz=sz)
train_dl = DataLoader(train_ds, batch_size=bs, shuffle=True)

# validation data
valid_data = datasets.ImageFolder(valid_dir)
valid_ds = FishDataset(valid_data, bb_json, sz=sz)
valid_dl = DataLoader(valid_ds, batch_size=bs, shuffle=False)

# %% [markdown]
# ## Classification with Localization

# %% [markdown]
# ### Model

# %%
class ClassifierLocalizer(nn.Module):
    def __init__(self, model_name, num_classes=8):
        super(ClassifierLocalizer, self).__init__()
        self.num_classes = num_classes
        
        # create cnn model
        model = get_model(model_name, num_classes)
        
        # remove fc layers and add a new fc layer
        num_features = model.fc.in_features
        model.fc = nn.Linear(num_features, num_classes + 4) # classifier + localizer
        self.model = model
    
    def forward(self, x):
        x = self.model(x)                    # extract features from CNN
        scores = x[:, :self.num_classes]     # class scores
        coords = x[:, self.num_classes:]     # bb corners coordinates
        return scores, torch.sigmoid(coords)     # sigmoid output is in [0, 1]

# %% [markdown]
# ### Loss Function

# %%
class LocalizationLoss(nn.Module):
    def __init__(self, num_classes=8):
        super(LocalizationLoss, self).__init__()
        self.ce_loss = nn.CrossEntropyLoss(reduction='sum')
        self.mse_loss = nn.MSELoss(reduction='sum')
        
    def forward(self, scores, locs, labels, bboxes):
        # Cross Entropy (for classification)
        loss_cls = self.ce_loss(scores, labels)
        
        # Sum of Squared errors (for corner points)
        loss_r1 = self.mse_loss(locs[:, 0], bboxes[:, 0]) / 2.0
        loss_c1 = self.mse_loss(locs[:, 1], bboxes[:, 1]) / 2.0
        loss_r2 = self.mse_loss(locs[:, 2], bboxes[:, 2]) / 2.0
        loss_c2 = self.mse_loss(locs[:, 3], bboxes[:, 3]) / 2.0
        
        return loss_cls, loss_r1 + loss_c1 + loss_r2 + loss_c2

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

model = ClassifierLocalizer(model_name)
model = model.to(device)
    
criterion = LocalizationLoss()
criterion = criterion.to(device)
    
optimizer = optim.Adam(model.parameters(), lr=0.0001)
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=1, gamma=0.95)
